# %% [markdown]
# # Assignment no 3
# Name: Vishal Pattar \
# Roll no: 33557 \
# Class: TE AIML \
# Subject: Machine Intelligence for Data Science

# %%
import nltk
import csv
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import opinion_lexicon
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('opinion_lexicon')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vishal
# [nltk_data]     Pattar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Vishal
# [nltk_data]     Pattar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Vishal
# [nltk_data]     Pattar\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package opinion_lexicon to C:\Users\Vishal
# [nltk_data]     Pattar\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# True

# %%
# Sample polarity words
positive_words = set(opinion_lexicon.positive())
negative_words = set(opinion_lexicon.negative())

# %%
# Function to preprocess text
def preprocess_text(text):
    # Tokenization
    tokens = word_tokenize(text.lower())
    
    # Remove stopwords and non-alphabetic tokens
    tokens = [word for word in tokens if word.isalpha() and word not in stopwords.words('english')]
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(tokens)

# %%
documents = []
with open('Reviews.csv', newline='',encoding='utf-8') as csvfile:
    csv_reader = csv.reader(csvfile)
    for row in csv_reader:
        documents.append(row[0])

# %%
documents
# Out:
# ['text',
#  'think crocs around cbn 1jagan 2modi 3amith shah 4kcr',
#  'election commission puts modiâ\x80\x99 kisan scheme hold till election the new indian express ',
#  'rahul respect masood azhar know that all bhakts are experts lying and spreading fake news about gentleman rahul and yes comparing hitler modi gentleman rahul not fair',
#  'check how successful the government has been fulfilling the promise the quintâ\x80\x99 election chaupal reached nagardhan village the lok sabha constituency ramtek\r\n',
#  'seats belong the party families asks modi times india â\x9a¡shawâ\x9a¡ ',
#  'modi not rajiv and rahul not singh probably that the reason',
#  'may summer time give recovery modi modi',
#  'modi sarkar already announced tax rebate upto lacks the budget',
#  'result notebandi ordered modi unauthorisedly ',
#  'surprised see that baseless allegations made such imortant matter national interests ',
#  'great whatâ\x80\x99 concern â\x80\x99 initiative which reached logical conclusion concerned that modi took credit instead congress why worried not congress right just enjoy the achievement india',
#  'attack modi our brave army ',
#  'correct definition modi  ',
#  'all antiindia forces have united stop modiwhilehis agenda building new robust india their agenda stop himthey have you with modi you with india you are not with modi then you are strengthening antiindia forces',
#  'congress were fools bet rahul gandhi priyanka gandhi would have demolished modi 2016 itself',
#  'well bhakts and rss anyways have already given their advisory that you dont support modi you dont support india vote right unless bjp doesnt have the right candidates win elections are you that scared vote consolidation the population ',
#  'accept suggest alternative modi putting your hands your heart jai hind',
#  'great lesson for india here modi dying get help from taking army his campaign trail',
#  'congratulations our honourable priminister shri modi for historic performance our scientists bharat modi ',
#  'this has nothing with elections\r\nand bahanji you are confident about wining these things shouldnt bother you modi has done nothing years\r\ndont confuse voters such lame statements',
#  'how many has that sence that talking abt for that ignite\r\nppl shld know the harm loan waiver and untargated subsidy naya new tragedy\r\nmodis targeted will good move gradually inc amount and make sure farmer knows there wont waivers future',
#  'panditji without taken anytime washout jehadi islamic from vellie bjp modi west time atal also sleeping nehruian left bangal biahri journo doesnt have right talk our north india part kashmir why burkha ndrv unu interface just blast amu jnu now enough enough',
#  'all these men except lalit modi were given funds during the upa regime lalit modis case different but firstly let know what the congress has done punish these people',
#  'india election 2019 latest updates via thanks ',
#  'modi hatao desh bachao war cry raucous crowd cheer her ',
#  'but mam still with due respect and your terms the role chowkidari unaccompolished not able save the lives fellow indians hostages iraq not able restrict the fleeing mallyachowksi and modi ',
#  'modi bhakt please telecast odishas bjp mla candidate from hinjili insulting elections observers show your courage modi bhakt\r\nà¤¾à¥\x87à¤¶à¤¬à¤\x9aà¤¾ ',
#  'only more thing need modi again',
#  'there was political will need anyways saraswat sir oru mpmla seat parcel ',
#  'trivia question\r\nname the only india have lost war\r\nyour options are nehru indira gandhi atal behari vajpayee narendra modi',
#  'honourable this very first tweet and feel proud send this message whatever the enemy within says about you with you all respects country needs you for the nxt yrs bless you god will guide you',
#  'generation next generation will all for congress have seen all pms india since independence all maintained dignity pms post except modi',
#  'modis marketing reality ',
#  'tweet modi postpone the practicals',
#  'out 130 cror only cror are illeigble vote cror pigs will never vote for modi balance cror dalits yadav sikhs upperclass hindus will divided among allopposition parties\r\n2014 bjp got cror votes 2019 may cror upper class hindus use nota ',
#  'modi need your help',
#  'power modi ',
#  'unfortunate that have moron like you the leader the opposition this country youre hatred for modi has turned you into antiindian the eyes many this country you may not care right now but soon you will have wait for that day',
#  'bad news gut feeling modi will pull through bjp will ',
#  'well done bharat sarkar and chowkidar narendra modi\r\nthis the sinister mahoul contributed article 35a whose proposed removal being met with shrieks outrage from the incleftseculartukde regiments ',
#  'you need good mental doctor just see this picture and than talk who poor first try help poor people your country who needs cloth foodpeacefreedomlots innocent muslims killed gujrat modi first try clean your home than try mess with your father ',
#  'modi address rallies bengal april ',
#  'recent reports suggested that labour participation rate lpr has actually worsened further under modi reignthe unemployment rate stood serious the lpr was 426 during the period while the global standard around ',
#  'want remind all those who are day dreaming about congress promisesfake and false that congress never even delivered the promised subsidised lpg cylinders year compare that with actual delivery modi government ',
#  'kia nahi humre wapis missiles marne per modi shalwar geeli hogai the way dont treat our enemy barbaric way treat them guest and teach them lesson humanity state terrorist kulboshan abhinanden',
#  'modi cancelled once again kya harami clickbait tha',
#  'not congi but this very below belt and bad taste without proof response somebody questions modi virility abandoning wife etc will also bad',
#  'police reform â\x80\x98mumkinâ\x80\x99 but the political executive has failed make happen\r\n',
#  'pakistan suffered most humiliating defeat 1971 when modi was nowhere politics bjp was not even opposition army who fought war not bjp congress',
#  'nehru deserves credit but modi does not than congress asks bjp why they bring nehru every defence  ',
#  'rahul gandhi added another one his lies deceits promising â\x82¹6000 the population costing 360000 cryr closing down schemes whereby shri modi already delivering more than â\x82¹ 535000 cryr â\x80\x99 old half filled wine old leaking bottle ',
#  'ask modi what was 6000 per year fools dont understand soon',
#  'yes credit goes modi cause taken this pic for that only ',
#  'sir said not with modi you are anti india thatâ\x80\x99 harsh statement',
#  'cantyou see very strong modi wave across hindustan\r\ndont write what you wish',
#  'mam ask the same question your brother mom both sitting mps modi and have many other responsibilities still made grass roots changes his constituency one suggestion why dont contest from banaras defeat modi and visit villages ',
#  'promoting modis thanks dynast',
#  'big achievement modi sarkar  ',
#  'agreed universal basic income not communism the need the modern times but anyone who capable delivering the most efficient way narendra damodardas modi',
#  'why are your channel oppose minimum income guarantee scheme your channel not opposed when modi gave huge rafale contract incompetent man who has 45000 crore debt only say that you should support good scheme',
#  'had totally Â£ gujarat watch some international investigative documentaries how much damage has been done environment gujarat under modi rule',
#  'bacche grenade phenkne mai bohot baara raaz chupa haiaaj subah convov per blast koshish phir yeh and aage aage dekho aur kese blasts hoonge sponsored modi and then will blame pak and will gain votes like this',
#  'never far know modis address the nation related the lets wait  ',
#  'modi liye baaki details dekhne liye watch his movie coming soon theatre near you',
#  'from dictating terms they have come the level urgingrequesting india all credit for modi ',
#  'just warned youdiscretion yoursgood good modi india moon mars per jai are happy for you',
#  'â\x80\x9cpakistan main biryani khane liye toh woh gaye the â\x80\x9d priyanka gandhiâ\x81© replies modis questioning nationalism opposition ',
#  'this time for only narendra modi',
#  'please modi held this bastard soon possible ',
#  'what else can expect from such fellow snooping went beyond borders gujarat modi wanted know about womans love life ',
#  'modi chor traitor modi sacrificed indian soldiers win elections vote for modi bjp anymore',
#  'bro mere nai hen help grow thanks',
#  'modi said antisatellite missile destroyed live satellite minutes\r\nindia has entered its name elite space power antisatellite weapon asat successfully targeted live satellite low earth orbit\r\nmission shakti operation was difficult target ',
#  'asat amid modi brag some key policy queries for your sunday reading',
#  'aur haa aapkay silent admirers kabhi comment nahi karengay they are just liking your comments just becoz you are speaking anti bjp same what congressman famous for speak against modi and shall promote you',
#  'they are the ones who have been sowing the seeds for decades and modiamit reaped the benefits will just spread faster rate now hatred eventually engulfs those who breed them',
#  'modi now antariksh chowkidar that mms could not ',
#  'because this suits modi',
#  'love for modi hate for dynasty',
#  'bhim army chief chandrashekhar azad campaigned varanasi modis constituency varanasi bhim army chief chandrashekhar azad saturday launched his lok sabha poll campaign holding roadshow prime minister narendra modis constituency varanâ\x80¦ ',
#  'samjh payega you need everything for free all developed countries are develoved because technology you dont even know the first letter technology and you troll modi and scientist',
#  'opposition disheartened with indias growth alleges modi arunachal â\x9a¡bjp president amit shah ',
#  'saluti there your unroll thread the most underreported disaster modi govt has been its attack our environment its not exaggeration say â\x80¦ share this you think its interesting ',
#  'worried about religious tolerance that has deteriorated and religious freedom violations have increased india under prime minister narendra modis regime since took over 2014 ',
#  'nirav modi threatened kill witness and destroyed evidence after spending ten days one â\x80\x99 most overcrowded prisons modi was again denied bail westminster magistrate court friday ruhi khan reports ',
#  'plz win action modi',
#  'previously leader spoke political language but now army personnel speaker such speech hes first modis chowkidar ',
#  'surgical strike credit goes soldiers not modi air strike credit goes soldiers not modi mission shakti credit goes drdo not modi raid cbi raid credit goes modi only did mentality oppositions ',
#  'that vicious lying opponents modi will intensify their viciousness but the only answer that vote modi again ',
#  'youre confident pappus ability defeat modi ask him contest from varanasi forget modi running from his family bastion for decades amethi since even daf dude like him knows bound lose',
#  'orgasmic moment for modi only minutes',
#  'post raids makes sure that airtime given bjp rest including congress\r\ncan one believe impartiality when who openly participated modis election rallies 2014 their poll expert',
#  'want modibjp',
#  'live nirav modiâ\x80\x99 bail plea will heard the westminster magistratesâ\x80\x99 court shortly\r\nmore updates\r\n',
#  'hey where ujjwala gas connection she using mud oven where consult dharmendra pradhan and modi and reply where lpg\r\nwhere lpg\r\nwhere lpg ',
#  'congress moves election commission not allow the release narendra modi biopic ',
#  'modi needs tell the gathering whatâ\x80\x99 store for them country general his balance sheet promises achievements corrective action for misses all these what proportion for modi any bjp leader shd decide',
#  'betrayal then even modi has betrayed india many times pakistan betrays slam them when indians like modi amit shah nirav modi lalit modi the list endless betray india should praise them ',
#  'difference between chor pappu and confirm modi',
#  'modi during modi wave also contested from two seats offense',
#  'imma standin right the petrol pump mate aint gonna work this time',
#  'drdo exchief mission shakti upa â\x81¦ didnâ\x80\x99 give nod but â\x81¦ had the courage india news the indian express ',
#  'today officers raided few powerful pwd officers karnataka\r\nimmediately kumaraswamy entire jds threatened protest against modi all over india but check what dept has found there ',
#  'india shot down live satellite elite space power now says modi ndtv ',
#  'come are you questioning the political acumen the great dont you know that modi the every state india head every panchayat',
#  'pnb scam nirav modi sought bail care for pet dog ',
#  'what about jumlas given modi lakh cheque crore jobs return black money etc fooled even educated ones like ',
#  'narendra modi engaged celebrities increase his twitter visibility study ',
#  'you are trying twist per your ease talking his hypocrisy \r\nsituation has only worsened since 2014 else why should modi bribe farmers ahead polling ',
#  'tweet 26319 yesterday indian airforce get ch47f chinook induction chinook â\x80\x98heavyliftâ\x80\x99 helicopters that all happened with transparent policies leader like modi  ',
#  'get well soon with india and against modi',
#  'many people are asking why did modi announce the success and not the scientists heres excerpt from the conversation between the then indira gandhi and squadron leader rakesh sharma 1st indian space was televised live was she scientist ',
#  'narandra modi good prime minister indiahe always step country development',
#  'spell out stand our proposed scheme for poor congress modi â\x9a¡ ',
#  'request pmo office publish data all parties who made politics family business giving seat their family membersleadership bjp under modi proved that politics serving country not family business ',
#  'and coming gender again sorry nirmala mam was considered then still certain ppl wouldve condemned saying should given tejasvini that clearly says its not about gender and about her see the bigger picture modi wanna vote other choice',
#  'shows your insecurity becoz india has aknowledge the fact that congress will lead india groop darkness dont worry modi coming again remove your illusions',
#  'its not developmentin fact this rogue system has developed generated big chain cheat millionaires billionaires for its particular interestswhats neerav modi vijay malya billionaire cum scam players now elections near they being trapped',
#  'may beat modi dramatics but pinaki beyond his reach',
#  'how modi govt reduced corruption with innovative steps ',
#  'around million advertisement spent modi govt last years ',
#  'think modi mistake fine mistake can resolved think people andhra',
#  'chowkidar arabind kumar chowkidar good politicians working honestly for everyonehe strong decision makers modi hain tho mumkin hain bharat maata jai bonde maataram jai hind ',
#  'dear akshay had done such big successful launch 2012 also but our educated manmohan that time did not make such filmy announcement manmohan singh allowed the chief drdo take lead and make announcement everything modi electoral propaganda',
#  'once again vote for narendra modi bjp will deport each and every intruders from ',
#  'good ',
#  'and ask the liar modi his own minister nitin gatgari said that 2014 election campaign said that time thought wont come form govtwhat you know about politics and ask your friends whether modi said not',
#  'unfortunate mambut hurts that its becoming the truth every partyand kind feels that they are abusing their power wellcoz people love modihe nice guybut all these low level officers just spoil everything',
#  'mig right citizen there shame hold state accountable how these basics democracy escape you welfare scheme complemented job creation too btwn whats your reaction modi govt assistance farmers same not why not',
#  'love modiji the nation proud sir there noise space\r\nmodi once more ',
#  'caught camera bjp minister caught touching lady inappropriately stage modiâ\x80\x99 rally ',
#  'now waiting for vijay mallaya nirav modi prefix chowkidar begore this names twitter',
#  'congress colluded with cia get scientists killed arrested false allegations stop therm from achieving such milestones now congress should refrain from bashing modi for speaking about feats under his party rule ',
#  'sapna tum itni himmat rakhti apne desh liye aisa bolosuch shameless lady you areexpected tha tumsehow much really you know about ambani and modithey did not call you for any performance now',
#  'reasons vote modi transaction charges through card down from domestic money transfer fee down from 2014 zero ',
#  'please lesson message about our country very important information regarding shri narendra modi giving message please',
#  'video ready debate you says modi vows â\x80\x9c paper teleprompter â\x80\x9c ',
#  'only chowkidar 2019 wanna modified india again',
#  'modi all are with ',
#  'just for fun sake pls praise modi again for anything that may feel like would love see bonkers again the name modi sends her tizzy will fun please ',
#  'asat operation due isro scientists\r\nsimilarly operation department officials why blame modi ',
#  'basically are agreeing that modi has failed deliver peace kashmir and have hopes him',
#  'join namo again youth club through watsapp message above number with parvesh verma kaho dil modi phir ',
#  'yeah friend are all trying teach subject known cricketers around the world â\x80\x9cspirit the gameâ\x80\x9d this gets ugly ipl will recall lalit modi savior',
#  'will any government india please run indian railway its time kyu modi kya kehte ',
#  'said that has already conducted surgical strikes from three platforms land air and space whats next\r\nwill the next conducted water also get chance otherwise will feel ignored all eagerly waiting for this',
#  'modi namumkin hai rows empty chairs modiâ\x80\x99 meerut rally via ',
#  'wrong did modi ',
#  'these are naxali supporter other word urban naxal now its clear enemy india siding with congress defeat modi',
#  'are having flat discount all our products all require your promise support namo the upcoming elections and vote for better india ',
#  'narendra modi nominated for nobel prize for physicsspacescience for designing and developing indiaâ\x80\x99 antisatellie missile',
#  'pakistan waiting swords drawn until the election done pakistan will not part modis pre poll rigging ',
#  'the income support promised congress bluff announcement modi government already giving rs106800yr through dbt subsidies simple arithmetic rs72000 for five crore families works out rs36 lakh crore which less than 23rd what being given ',
#  'congratulations your international debt crossed half trillion dollar and reached billion another great achievement modi after highlighting kashmir issue internationally fake air strikes and using planted attack their own arm forces pulwama thanks modi ',
#  'former bjp leader ghanshyam tiwari joins congress via modi chowkidar rich says rahul gandhi rajasthan via ',
#  'see barely anyone protesting against the forced conversion the hindu girls pakistan entire modi hater brigade silent',
#  'modi has already delivered money farmers bank account and your pappu delivering unachievable dream one bird hand better than two bush the way what happened your promise 10000 per month for unemploymed youth and farmers loan waiver ',
#  'people very well know that are the worst corrupt political party india led modi and amit sha people will vote against bjp bjp leaders are all corrupt and crooked order save india from corrupt bjp vote for congress party',
#  'not journalist you are leased karyakarta now hardly read any thoughtful article\r\nonly political posts that too anti modi and pro congress this what has ruined indian media',
#  'had congress been playing for win would stitch alliances and not endanger them just playing for beating modi propping numerous small discontentssome sops here and there will bring down bjp votes just enough beat modi model being upscaled nationally',
#  'this actually achievement modidoval they have elevated strategic distraction pak overwhelming threat and swept under the carpet their ineptitide dealing with the more cogent strategic danger the chinese dragon looming over and all around ',
#  'amazed see your bhakti rather andha bhakti\r\nwill you please explain with proof what kind low inflation modi has created and what the benefit indian economy\r\n',
#  'lol she most negative passive person have seen just modi this and modi that now nyay second coming',
#  'can you something stop people outside karnataka talk about modi and his nataka want only prosperity and peace kannada mannu',
#  'rock star modi\r\nfight finish',
#  'invite you join support coming general elections visit join help shape banenge layenge modi dobara via àª¿àª\x82 àª¾ à«\x8bàª¾à«\x8b àª\x86àªªàª¡à«\x87 à«\x8bà«\x80 àª¾àª¾ à«\x80 à«\x87',
#  'assam has suffered due the incapability previous governments completing\r\ndevelopmental projects time but today assam moving ahead with skill scale and\r\nspeed under decisive leadership modi ',
#  'excellent thread jioh and hatersburn ',
#  'here the complete analysis with pure facts employment growth and job generation under the modi govt must read\r\n',
#  'modi built more highways than upa 2solar power output grew from 2000 20000 sagar mala\r\nrailway electrification\r\ninflation was when upa left now its below cad from below either didnt voted for bjp after voting went into hibernation',
#  'liberal liberal hate fascist modi some celebrity will support modis campaign asking everyone vote liberal god dont like this celebrity anymore irony cant even commit suicide against indian laws and sanatana dharma',
#  'wow modi hats off new india born',
#  'the biggest failure modi will addressing rural distress may cost him this election india shining want see which one will loose badly',
#  'railway station ',
#  'modi failed fulfilling his promises the slogan good days turned into nightmare the unemployment and spread poverty galloping now using armed forces hide his failure may god save the region from such politics which based hate bigotry extremism',
#  'another jumla exposed modi worst indias history ',
#  'the religion terrorist terrorism are seeing new phases these religions the form modi saffron terrorism and hindutva',
#  'kya hoga all updates below\r\n',
#  'why are you taking credit modi',
#  'dont worry only trump algos hote hein modi algos nahin hote',
#  'she was not ordinary orator people used connect with her just like modi and importantly she used take bold decisions',
#  'its historic day for india all are proud our scientists and modis government thank you jee and ',
#  'those are the real anti nationals',
#  'thanks former nsa may surmise this was custommade asat boost modis campaign scientists shouldnt have been ordered around election agents very poor reflection saraswat too getting exposed creating misperceptions public opinion ',
#  'what about modihe murderer the muslims',
#  'indirectly also means that captain modi ran away noticing the sinking ship when contested 2014 two seats what bunch hypocrites these bjp leaders are sigh',
#  'modi should apologise the country insult the poor comparing opposition political parties liquor says ',
#  'why this mob tried lynch isnt responsible for this violent behaviour budding goons',
#  'lies understand but who are you think bjp leaders are froud and his leader modis big froud that make jumla politics jago india walo sale sab befkuf bna rehe leyi nota button and reject all leaders who dont deserve this job',
#  'peopl are trying argue how faulty rahul gandhiâ\x80\x99 minimum income plan â\x80\x99 simple â\x80\x99 foolproof and sound modiâ\x80\x99 lacs each bank account plan was',
#  'modi urged celebrities from various fields motivate people vote ',
#  'modi hai â\x80\x98mumkinâ\x80\x99 hai wasnâ\x80\x99 the slogan bjp â\x80\x99 disgraceful for the post',
#  'â\x80\x99 2019 sunrisers donâ\x80\x99 win this season then there even modi wave',
#  'waiting for narendra modi promise â\x82¹ lakh everyoneâ\x80\x99 bank accounts once again  ',
#  'headlines india now global space power chidambaram flays modi over lakh â\x80\x98mathsâ\x80\x99 goa mgp mlas join bjp raghuram rajan doubts gdp data ipl csk beat wickets for more ',
#  'voting for ',
#  'kakaji shivajinagar would foolish expect fight antimodi makeshift with gandhian principles those principles are socialengineering tools which was best illustrated mkg himself ',
#  'nirav modi make second bail application next court hearing friday punjab star ',
#  'hola the unroll you asked for thread the most underreported disaster modi govt has been its attack our environment its not exaggeration say â\x80¦ talk you soon ',
#  '\r\npakistan still counting bodies but opposition keeps asking for proof modi odisha via namo app ',
#  'you know abhinandan getting captured foiled the entire plan modi modi would have preferred dead abhinandan because that wud have helped him beat the jingoism keep the war mongers alive and kicking but abhi changed the whole narrative blessing disguise',
#  'shivraj chouhan eve 2018 election said â\x80\x98 politicians can promise moon nowadays and people will beleiveâ\x80\x9d and lost loan waiver only implemented for farmers but who cares now let forward nyay 2019 lesson modi must show dream moon win',
#  'what all will people their fear hate for modi\r\nits sad',
#  '\r\nunder modi govt home not just dream anymore with decline home loan interest rate from 103 nov 2013 around now huge savings due lower emis are empowering middle class homebuyers',
#  'its india beheaded secular scholars every developmnt action important govt compete with intelligence 108 scholars whn matters india war begun with vision 108 scholars with comics theatres frm 11th april may23 ',
#  'dont you ever think this all earlier when you was power upa govt\r\ndid modi inspired you',
#  'project permission given scientists modi government modi also right about annoucement achievement',
#  'vajpayee govt put hard work develop india then upa ruined for years with corruption all around then for the last years modi govt cleaned the mess and took india forward not want the upa come and ruin again ',
#  'contest 2019 nda will win over 300 seats says prime minister narendra modi click here ',
#  'orey cbn corrupt modi supporter donâ\x80\x99 like him but please donâ\x80\x99 vote jagan jagan psycho and you would see real rowdy who has basic human values scares like anything even though â\x80\x99 from god saves please save yourself',
#  'rajdeep sardesai and you and many called journalists like you made hay upa rule now you are cribbing bcoz the free lunches and free booze foriegn liquor have stopped completely the whole lutyens brigade responsible for making modi national figure bcoz blinded',
#  'supreme court clean shit bullshit all know modi not saint either but yes aussie giving gyaan having sportsman spirit lmao hypocrite',
#  'hope not calling old person youngster waisting your time twitter people who can read and write are smart enough draw comparison between incs yrs vis vis modis werent born yesterday ',
#  'choti soch not with modi bol',
#  'and these people talk arrogance modi intolerance hatred etc etc when their chamchas say that their entire family first citizens the country indirectly saying their family uncrowned kings indians why priyanka gandhi should pay toll tax ',
#  'what modi contribution space technology canâ\x80\x99 claim credit for what our scientist achieved ',
#  'joy jagannath joy modi joy sabit',
#  'first tell modi â\x80\x99 lakh each indians account was jumla two crores jobs every year was jumla ram mandir was jumlaarticle 370 was jumla before pointing finger rahul fingers are pointing towards you only sir ',
#  'was not verdict modi rajasthan they said modi tujhse bair nahi madhya pradesh was very tough battle cong did not get majority chhatisgarh dont know what happened still not verdict modi',
#  'does again be4 the election commission decides the speech the media declared violation why cant stick only facts\r\nhow air doordarshan beat â\x80\x99 model code air modiâ\x80\x99 asat speech via ',
#  'shame ',
#  'imagine the mental state person who hates both narendra modi and ',
#  'puri people are very lucky have you jai jaganath jai hind modi again',
#  'finally our modi govt throws 21428 lifeline five psbs public sector banks the capital infusion will way preferential allotment equity shares the bank during 201819 modi govt infuse 42000 psu banks march',
#  'with the thingy comment your intellect understood also our money safe only after modi came power people like you will not know the concept honest days work',
#  'need read thank you let her write keep reading till modi service india cant you seeindia last years not sleptalways verge more check how many path breaking decisions schemes etc started modi govt they changed politics india',
#  'going leave amethi for wayanad like modi left vadodara for varanasi not then going there because afraid yes then amethi peopleplease keep this mind your times running away now from ppl ',
#  'hindus are being assaulted and murdered across the country how many have been butchered kerala why was ramalingam killed tamil nadu because opposed conversion your blind hatred for modi has resulted you playing into the hands the ugly katwe',
#  'thanks modi given ticket now will busy with his own campaign that and his thoughtsopinions will restricted bengaluru south  ',
#  'and read the speech mohd modi gave british parliament',
#  'did modi govt realize this only now after years power with the huge mandate 2014 was the govt the same quandary nehru and successive pms ',
#  'happy see you live sir modi modi modi\r\n',
#  'after election modi comes power will definitely build sauchalays for street dogs with tax type donation from lndian public per last records taxes will also rise upward even after this election 2019',
#  'saraswat hardcore rss guy who even attends rss shakha gia currently the scientific adviser modiyou pidis can fuck yourself',
#  'amir bhai tell time when all people india were having job and their was agrarian crisistill now were fighting election three items only roti bijli aur makaan now nobody talking about them dont see the difference what modi did last years',
#  'prostitution human rights abuse slavery torture how many women you know would want become prostitute ',
#  'â\x80\x9cmodi usual likes take credit for everything â\x80\x9d mamata ',
#  'the ambitious pradhan mantri awas yojana pmay the narendra modi government has made affordable housing reality ',
#  'narendra modi one evil stalkerhe simply unable spend min without thinking about pakistan',
#  'now have 100 per ent doubt modi and the irani coaliation',
#  'after ruling congress for years india modi has created two india waoo logic',
#  'great job well done modi best wishes dinesh bist',
#  'just ploy file nomination let get rejected due conviction and then claim persecution modi modi afraid hardik bjp ill treating patels etc',
#  'article cpi affiliated journalist nothing but completely biased one can also know from the list websites you are affiliated withwire quint etc all you want modi still better than corrupt congress',
#  'pls tell post independent major time cong and friends had power then why the fuck india still developing countrywhat the fuck cong did yrs before modi ',
#  'immediate deescalation what see one mistake from modithats all they want',
#  'well done her her modi',
#  'madum appreciate your work pledge vote for modi',
#  'absolutely correct congress party the proxy pakistan such rotten establishment devoid leadership skills harvard educated crooks rely harvard drop out save them from criminal prosecution national congress has become sonia congress modi for ',
#  'does not talk about the benefits bringing rahul gandhi power cheap theatrics from bimbo jumbo did you ask him why did give loans nirav modi and mallya doesnt suit your agenda',
#  'the bjp has made vidarbha big that its children are listening modis name only and the result that congress candidate getting the courage stand the election for congress vote killing daliproteks\r\n',
#  'two loosers are talking about winner modis policies want shed lights employment issues congress party and workers will jobless after the election but dont worry rahul will give them 72000 rupeesyear',
#  'anything against modi you start jumping and downcensoring words against the dynasty exisro chief your forte that your next show ',
#  'wowthe hindu article only talk antimodi comedianssatireif narendra modi film can considered propaganda same pseudoleftliberal logicwas election gimmick promote antimodi sentiments satire satire propaganda',
#  '\r\nyour vission clear could all see how modi answers for the questions and what pappu did 2014',
#  'priyanka gandhis varanasi hint would she give fight modi ndtv ',
#  'sir ladya modiya over now daddy all their corruption modis table poor anwar raja also line now after the raids',
#  'this idiot wants break india\r\nbut modi assaulting institutions india true democratic party india',
#  'air india rolls back boarding passes that had modiâ\x80\x99 image ',
#  'just seconds after one anti modi post airtel network has been shut while other sims are working from which havent posted anything this state sponsred surveillance and illegal censorship pls retweet and comment ',
#  'anteee bjp tho jagan understanding ochi bayata matram modi vote eyadhu ani chepthunata\r\ncomparison emi undi both are youth leaders india needs such youth leaders survive simple get out narrow prism and think 360Â° will understand ',
#  'you quote political science professor and come conclusion why cant you consult scientists and write article without that you come across modi hater than expert',
#  'dont play games modi ji2019 after elections bjp ripin india',
#  'know modi for last years and needs nothing and have your ideal has nothing against him rather one has dont waste your time playing modis strongest turf',
#  'credit goes modi',
#  'â\x80\x99 not mistake expect kcr become for pak and president for usa  but for india chowkidar modi enough',
#  'these people deserve modi fucktards',
#  'india successfully shoots down satellite space modi let all opposition fools comment anything they want has happened der the leadership our the credit certainly goes him why silent mouna mohan singh',
#  'kanwal more worried about modi than modi minister insulting his family live stage show',
#  'after listening the news ',
#  'has lost lost his mind with the ticket given him doesnt even know the basic conscience the constitution the right just spreading hatred its time send modi the cave since wants more chowkidar then ',
#  'modi also selling drdo products which years old apart from election undermining drdo who have achieved years ago',
#  'yet spell out his agenda for next years modi just trolling others ',
#  'brother selfgoaljagan praising modi and supporting kcr how can get chair',
#  'raju created modi photo framesphoto with modi\r\n',
#  'hes not lonely\r\nthere are many who are scared modi culture which making life corrupt helllike',
#  'khazana avb kee govt bhara and looted and lutwaye royal family courtier and few loyal like mallya nirav modi mehul choukse and when modi bring ibc then ran away rafael order his antony said money all looted our party with few',
#  'modi first time loksabha election larha tha tab woh bhi seats and tagde margin jeeta tha dono jagah idhar rahul gandhi apne years political career mein yeh pehli baar kar raha hai bcoz the chances defeat from the home seat fark hai dono cases ',
#  '\r\nsee the difference between modi government upa govt modi saved from scamscorruptions price rise external internal threats for ',
#  'its the local leaders who have talk about this let modi talk about his governments achievements talk about their manifesto',
#  'â\x82¹6000 wont the youth its meant for women only correct that following modi will make people blind because modi visionless leader hes only there serve the lutyens and the corporates',
#  'dis man embarrassment modi governmenthe needs get out debatessooner better ',
#  'absolutely rightif you are not with modi you are anti nationi agree',
#  'people india strongly believe country safe the hands narendra modi bjp truely people india have made their mind elect modi bjp lok sabha election 2019 people believe country very unsafe the hands immetured inexperienced rahul gandhi ',
#  'top bottom the bhukts only speak nonsense use abusive language like narendra modi because most them not have answers the questions being asked them',
#  'the makers have dropped the second song called reprise version originalâ\x9d¤ï¸\x8f ',
#  'sirwhat saying you are saying why should give chance for jagan and what didi questioning you what you people did sir past years\r\nexpect making useless comments modi and otherswhy shouldnt give chance for jagan',
#  'modi govt wonâ\x80\x99 act hindu terror left ',
#  'show video modi saying that give 15lakh',
#  'modi slaved got loans our nation may tell thru dmmake borrowerssigned mou all countries modi known not known and our family members ammk',
#  'but shri narendra modi proud chowkidar toilets too for the sake glorious indiain the path shri mahatma gandhi todays true heir bapu shri mahatma gandhi shri narendra modi jithis gets established from hispm shri narendra modi deeds',
#  'full form modi master developing india',
#  'modi have big announcement coming all news channels humare experts batayege kya announcement sakti hai',
#  'legal team make second bail application court today ',
#  'congress navjot singh sidhu attacks modi saysstop deflecting the real issues\r\nread story ',
#  'perfectly sums why need modi againz ',
#  'the same way modi factor worked assembly election bihar ',
#  'what the difficulty with narendra modi',
#  'congrats media you have been awarded with nationalism certificate from the holy pope may lord modi with you ',
#  'cpi marxist has power indias government through elections they collaborate with the state and enact policies kill and arrest maoist revolutionaries well are complicit modis neoliberal and fascist policies',
#  'wheat crop poor farmers jammu destroyed for modiâ\x80\x99 poll rally ',
#  'dear may loose bangalore south dont stop them they treating bangalore their inherited jagir you dont stop them they will what they did rrnagar and jayanagar stop them before its too late ',
#  'even kids know what india want modi modi ',
#  'culture and belief systems were cane about identify the very self humans and coexist then superiority among them lead different practices and led new religions vote for human values not follow religious leaders and bigots politicians like modi',
#  'dvs but modi victory 100 certain',
#  'just like modi not pappu',
#  'are you not the same cartoon who said now you babus dont listen political leaders because mcc that true how can modi ask delhi police commissioner take action lying then now kindly clarify',
#  'atleast modi himself not playing any card credit its the chronicles who shows modi coz modi take step forward for this mission',
#  'one more thing dont know how anti hindu women like madhu kishwer become pro modi after became 2014 know madhu kishwer used make fun atrocities kashmiri hindus and used have conference with terrorist yasin malik',
#  'yrs with all the tech his hand unemployment rate has shot 45year high under modi india was new country with all its complexities and feudal system still intact despite all these india still grew under nehru ',
#  'better not talk about congressignore themmodiji gave importance rahul and still pictureif right democracy rahul and family defeated and jailed for disproportionate assets and incomewill chowkidar modi ',
#  'appeal thechiefelection commissioner his team not undermine the national interests being safeguarded modi govt most efficientlyby ordering baseless investigations the name à¥\x81à¤¾à¥\x80 à¤¾ à¤\x82à¤¿à¤¾\r\nhow did cecforgot investigatecongresson offering rs72000to poor ',
#  'nirav modi must repenting for having fled india had stayed here milord would have given him repeated protection from arrest given chidambaram least bail given gandhi family ',
#  'what compensation did modi govn gave farmers india ',
#  'need chowkidar who can take care our borders imandar and zimmedar well like you vote bjp for and trs for assembly jai modi and jai kcr',
#  'its not modi its urgent congress and its reservation policysharam kar before twitting junk',
#  'hey porkistani mulla your country porkistan scared govtthey want congress govt india india under modi have completely isolated your country saarc other forums your country stands exposed whole month your airbase was shut ',
#  'pictures public celebrates jammus akhnoor during the narendra modis mega rally jammu ',
#  'very much disappointed with this tweet behalf narendra modi pakistan kill all hindus and sikhs forcibly convert their religion into islam destroy their religious palaces will india remain silent',
#  'usa defence secretary presidents talk presence generals just because chrislamist dont like modi should follow australia',
#  'west bengal ready embrace shri amit and bhartiya janta party ahead sir the country behind you and shri narendra bhai modi bharat mata jai ',
#  'everything modi does odd except when confers padma award presstitutes and free rides during his fgn trips',
#  'modiâ\x80\x99 way repayment debt and gratitude his benefactor the 2014 election joshi had vacated his varanasi seat for modi and then won kanpur record margin securing the votes ',
#  'air india boarding pass with modi rupani photos comes under scrutiny\r\n',
#  'uddhav thakrey seems confused man times will blast modi shah and then will hug them â\x80\x8dâ\x99\x80ï¸\x8f and for years people keep buying all these',
#  'the same for rahul gandhi and other congress leaders too these journalists want understand modi but still spread imaginary arguments but none them had still the guts ask rahul gandhi other congress leaders ',
#  'modi cunning there doubt about that tweeted week before february attach that modi would for air superiority war wins would say took revenge and loses would say needed rafael and that would help him justy controversial rafael deal',
#  'modi chairs ccs meeting after air strikes pok ',
#  'adarniya mayawati modi taking this country into the orbitand you are stuck into electionsyou want vikaas rightyou want jobs rightthis 100 indigenous india scientists dont you see vikaas jobs are you wanting jobs vikaas',
#  'sir leave him day day started criticize modi but all know expect him whom have vote rahul ',
#  'logo milna jaruri nahi hai bus unka bhala karte raho which modi did does and will future too â\x80\x99 not like end five years affair wearing saari and cry poor poor',
#  'who out bail modishah duo maan bete duo your are correct the one who screams chor chor the real suspect chor because they want divert attention elsewhere\r\nnamo again again',
#  'opposition parties will have copy modiâ\x80\x99 permanent campaign trick sooner later shivam vij writes ',
#  'whining idiot cringing out now when finds that his hands are tied that not able scrounge aroundâ\x80¦ has more questions staring stark him wits end\r\nâ\x80\x98modi mistakeâ\x80\x99 chandrababu naidu tweets counter â\x80\x99 â\x80\x98uturnâ\x80\x99 jibe ',
#  'must read modi bhakths say there are jobs for our youngsters bjp supporters say job opportunities india have gotten worse last years pew research center survey ',
#  'election commission sets committee probe narendra modis address nation violated poll code concerned must look into poll promises which amount bribing voters vote viz free income scheme etc etc what doing',
#  'infringing the autonomy educational institutions rewriting school textbooks and palming off myth science the assault reason modis india ',
#  'pls promote using tweets fits any pro modi tweet ',
#  'à¥\x88 à¥\x80 à¥\x8cà¤¾à¥¤ gurdian modis one liner for 2019 electionsâ\x98ºï¸\x8f',
#  'this picture aptly defines what modi claimed today via ',
#  'modi saying but want restart his loot whitebribing indians with sitathome benefits making them lazy self induced unemployed citizens',
#  'indeed look the ones who are crying main desh itna pyar nahi karta jitni modi nafrat karta hun ',
#  'oppn parties â\x80\x98disheartenedâ\x80\x99 indiaâ\x80\x99 growth says rally arunachal via ',
#  'wht ant rahul gandhi ranting day day out with always proxy not even aware wht going ard him modi rafale anil ambani not asking yrs wht congress did last yrs only chidambaram sonia gandhi kapil sibal vadra multiplied their assets much tht',
#  'are you saying that modis aura and following comparable gandhis aura and following pre 1947',
#  'pakistan gives green signal for opening sharda peeth corridor reports modi hai mumkin hai via thanks ',
#  'expect global times etc deepen its antimodi rhetoric',
#  'our beloved narendra modi the only hope 130 billions without you will become orphan you are the only source energy inspiration for every honest hardworking indians voice very common manjai hind',
#  'proud modi for such magnificent achievement great success mission shakti',
#  'india enters elite space club after scientists shoot down loworbit satellite 300km away space says prime minister modi via ',
#  'ohbuddy dont rude check the video modi big announcement once â\x98ºï¸\x8f',
#  'you dont bothered that have move this directions next war satelite war only you not done but modi has think and give nod programme and budget see the result this the difference ',
#  'foolish narrative being circulated modi bhakts',
#  'sport modi and you',
#  'achrya sabse gira hua tum hai are taxpayers will vote for modi ',
#  'all know modi did didnt its about pakistan relationship gather courage challenge man named  ',
#  'let tell you north karnataka out constituencies will dominated bjpgulbarga central karnataka davangere shivamogga chitradurga and ballary will clean sweep for bjp considering modi wave and dominance lingayat community',
#  'what this kid imagining now did years back ',
#  'the nonsense lady cant figure out simple thing mnrega wiped out the farm and construction labour most parts the country modi had repair and restructure ',
#  'not mislead the people our state publish the report you are referring here read this publication attached here the crime against women increased during modi govt centre ',
#  'still vote for modi and make sure congress dies',
#  'welcome gohpur assam modi proud moment for ',
#  'this things they will unblock 1hate narendra modi praise rahul gadhu know its toughbut thats the only way',
#  'credit for all scams congrress shameless congress did not have guts give ahead drdo expert looting and misguided youth india dividing people india india changing nowonce more modi jee  ',
#  'demonetisation was massive disaster for the economy modi tampered and manipulated the gdp data unemployment year high everything points single thing modi failed our economy',
#  'you might have earned too much modi raj that you and your next two generations need not think about ',
#  'modi and bjp the only choice for jammubcoz this time couldnt happen remove article 370 and 35abut they only can expect soin congress time islamisation was full speed',
#  'doubt credit given where due modi too accepts these credit problem with current leadership ',
#  'are proud narendra modi our ',
#  'â\x80¢ vijay mallaya was congress rajyasabha â\x80¢ rahul gandhe visited nirav modi his house the day before escaped fearing arrest modi government â\x80¢ lalit modi the best friend and business partner rajeev shukla who congress leader ',
#  'win win priyanka will restrict modi into campaigning varanasi and largely helps inc overall',
#  'whatâ\x80\x99 preparedness when party shrinking day day all its preparedness amounts hurling abuses narendra modi',
#  'narendra modi fir jitna hai dosto all indian people are plz support for narendra modi ',
# ...
#  'this leader better whatchest thumping criticisingevent managementjust one examplein any fieldof any such project compared what build achieved from previous past projects yes afcourese sardar patel statue thats the only visible project modi build',
#  'check out the mission shakti tweets and you will know why they have made modi issue they swallowed the biscuit and yet realise ',
#  'bad they are from tamil nadu\r\nand doubt brother spreading fake news',
#  'had prove his loyalty his kingmodidisgusting rajib ',
#  'modi interact main bhi chowkidar supporters today more than 400 via ',
#  'modi once again modi government works hard empowering the state covering\r\ninfrastructure manufacturing housing healthcare msme and all other sectors\r\nthat come under budget 2019 ',
#  'what modi has done has done nothing stop the violence but was directly consult with babu bajrangi very ashamed what play role ',
#  'dont say this hemant whenever modi was foreign trip never asked for votes',
#  'stupid people unnecessarily blame modi its god responsibility provide foodjob etc ',
#  'spoke hindisena deshwasion liye ladi mere liye ladi â\x80\x9c and went add one party can claim credit for the success our sena modi shah stop the noise that only you care for this nation and others are anti nationals',
#  'absolutely amit shah sir har har modi',
#  'support only modi sir ',
#  'your xxxxx699631 credited inr 7200000 290319 deposit transfer from indian national congress bal inr 157200000 15l modi wale hai hope will get this msg coming days ',
#  'before modi entered politics india entered space mathew kuzhalnadan shoba surendran\r\nfound very apt',
#  'gujjus dumped modi shah combine ',
#  'rahul gandhi inherently transparent honest and identifies with every indian with him lies hypocrisy falsehood modi rule will thing past ',
#  'mamata banerjees shameless appeasement policy and politics discrimination has crossed all limits tolerance shall not able hold modi tsunami ',
#  'modi make important announcement soon ',
#  'very good young energy salaam many many congratulations dear aao jaise young energy must required parliament\r\nmodi and bjp hai namumkin convert into mumkin\r\nvote for modi namo again',
#  'modi work hard you not have skills will provide you need finance will provide\r\nrahul not work will give you free money that you remain poor need come back next election ask for votes bring back power for garibi hatao',
#  '200Â\xa01900 gifts and memorabilia received modi auctioned and 117 crores added namami gange fund crore seoul peace award also namami gange has any leader has achieved much years its one and only modi india will develop and prosper only with modi',
#  'this election narendra modi was win win 2019 ',
#  'agree with your view dictater modi',
#  'rahul gandhi said niti aayog set modi 2014 served purpose other than making marketing presentations for the and fudging data\r\n',
#  'and what about congress which keeps saying modi helped you run away ',
#  'this election have only agenda good modi bad modi but the lead roll the power hindusm hindu san mullo par bhari namonamo',
#  'bataiye media bhi campaign promote karr rahi  instead saying listen her she saying ',
#  'lord rama abandoned the throne went into exile himself and rescued maa sita sat the throne himself abandoned his wife jasodaben hindutva thugs call him reincarnation lord rama what disgrace the name lord ram ',
#  'has done nothing and won election because modi let fight out this time and see wins',
#  'this expert committee fraud committed modi confirms that evms are rigged lakh evms programmed shift every third vote bjpresult will flawed ',
#  'understand your pain modi should have credited this nehru',
#  'time has come support modi govt ',
#  'those who are employed also need better condition work modi govt responsible for bad economic policies which directly impact working conditions ',
#  'while modi was busy touring foreign countries hugging all the leaders for nothing youth india were streets searching for jobs while india suffered amabani adani rejoiced letâ\x80\x99 throw this tyrannical govt out vote for congress httpst',
#  'your did not have the balls condemn chinas treatment uigjurs dont talk about modi making pak shit bricks you can build your houses for free ',
#  'your xxxxx699631 credited inr 7200000 280319 deposit transfer from indian national congress bal inr 157200000  lakh modi wale hain â\x80\x94 vibgyor school airoli ',
#  'jobs â\x80\x93 promise made and delivered the modi government via namo app\r\n',
#  'nice decision taken modi shah the terrorists have place civilized society who destroyed babri masjid',
#  'dont want uturn modi pakkodi â\x9c\x8c',
#  'did modi take bribe beholden corporates for influencing election hell yes ',
#  'cant expect anything else from rld goonsif these rld goons will come power repeat same roadshoping people baghpat have judged themdifferentiate between discipline rude party vote for nationmodi vote patrioticvote hindu',
#  '\r\ncitizens support india that dynastyfree corruptionfree terrorfree safe for all its citizens people the nation supports modi who works tirelessly for improving the lives all let also pledge the chowkidaars support the',
#  'sir you dont need answer such self proclaimed journalists whose journalism dependent upon jio simcard free data they themselves are highly biased abusing modi army isro etc just make there career masqueraded were just asking questions',
#  'always with you narendra modi thank you for all your efforts for our nation are proud you',
#  'who ever says this anti national because you think modi above democracy talk hand ',
#  'fakeer ',
#  'they are just modi jis employees boss boss',
#  'when say modi will return power with higher mandate friends say its overconfidence what proof source all things see this from enemies mouth  ',
#  'look this lutyens sickular called journo coupletheir mumbo jumbo think mahine maska kist abhi tak mili nahin lagta hai and when the scientist himself crediting modi and saying upa was indecisive now says scientist also taking side height ',
#  'really read this ',
#  'not better than mudra yojna modi',
#  'there only one candidate modi thats ',
#  'respected modi request you please stop the rally india during any election session and the expense over the rally amount paid completely election system and every poltical party should deposited decided security with election commission india penalty',
#  'another andh bhakt swami but have appreciate him atleast spoke true once times but modi forget say truth for him lie the language ',
#  'anybody but modi',
#  'modi will still remain our prime minister',
#  'modi wholesaler can keep some salesman generate employment',
#  'cute now get lost  indian terrorism pay time about begin fab was just example for you next time will bomb modi head terrorist south asia ',
#  'rahul gandhi today you have proved once again that you cant modi',
#  'were against arms raised space this test wont breach any international law treaties modi ',
#  'spaced out ',
#  'another countries what happened why you blame others blame modi because our and has the responsibility stop ',
#  'like you agree party ',
#  'terrorists mentors stand terrorised will now think 100 times before infiltration modi ',
#  'pms poll blitzkrieg this time modis mantras included comparing the opposition sharab and himself the protector chowkidar vivek reddy sharat pradhan and sudheendra bhadoria are the show ',
#  'modis very talented person sure win',
#  'â\x80\x98modiâ\x80\x99 name our work will give bjp seats this lok sabha electionsâ\x80\x99 yogi adityanath hindustan times via ',
#  'population and pollution control modi failed control ',
#  'that great one more surgical strike modis fakenationalism @',
#  'have you ever thought facemaking advertisement expensesrs 5500crores modi was used for poors what had happened have ever thought fraud ayushman bharatfarm insurance scheme money was used for poors rather than giving private insurance companies unbiased',
#  'phele rahe the modi diya yeh announce kar rahe farmer loan maaf kyo nahi kiya why kept public poor all there life ',
#  'only rajdeep has the right take sides others cant but unfortunately repeated the word disaster how badly even scientists want modi win the election',
#  'limit frustration and loss confidence modis poems translated urdu and published ',
#  'you have courage then came with your present name and title second thing you are the party which best fitted for you last you are new born baby dont behave like your mentor sanjoy nirupam you blaming modi becouse you have the freedom',
#  'talk about looting hypocrite modi took white money converted black gave trolls everone knows who else',
#  'now â\x80\x99 very clear that the opposition who are opposed mrmodi are only interested self development especially wealth and are trying their best destroy the country due fast communication spread knowledge â\x80\x99 becoming very very difficult for opposition ',
#  'twicking laws help capitalist friends before code conduct for à¥\x87 à¥\x8bà¥\x80 à¥\x8cà¥\x80à¤¾à¥\x80 ',
#  'this not modi this rahul   ',
#  'are indians fool stupid tht they cant thru modiâ\x80\x99 optics tactics they refuse see keeping quiet waiting answer ballot box wish the last action everyoneâ\x80\x99 mind heart',
#  'calling voters corrupt with these words thinks deserves modi humiliates the voters doesnt want our vote fine will lose wait watch',
#  'ajay singh bisht will used bengal and orissa communalize the voters\r\nbut the besides dalda hindu one will vote modi india ',
#  'remember poor people those who has run away vijay malya nirav modi mehul chokshi type ppl were given money congress lead upa govt corruption top time obviously congress leaders must have earned money for such generosity thieves',
#  'but never understand someone praises modi why are they termed bhakts mean being muslim obviously biased and can never modi fan but donâ\x80\x99 call him pappu fan',
#  'every indian benefitted modi government',
#  'because all these yrs pappu his family was looting the country without paying attention common people has ever congress cared about the cleaning ganga modi who said that would clean ganga per his promisethe project will completed 100 next march',
#  'yeah its more real than someone with bush its avatar fake farmer pic lmao tumhari toh itni jaal rahi hai iaf kay total failure pur pakistan salaam chowkidar modi pur',
#  'now pidis will say navy pending modi kuch kartha nahi',
#  'self marketing limits exceeded modi right',
#  'best luck sir all together will elect modi india again',
#  'dear all heres continue running modi plan for india ',
#  'meaningless exercise where they are unaware and unsure the scheme details and peddle the lakh made story plain stupid just shows that the entire sham exercise born modi hate derangement syndrome out spite desperation nothing for the people',
#  'according does conspiracies while cute innocent kittentoo much forwards making grey matter brain darkif this what for livingplz find real jobif this hobby love for modiplz raise bar',
#  'ache din agaya airports donâ\x80\x99 start security check even mins before the departure flights wah modi wah changed the fate airports from 2morrow people can arrive mins before flight like trains',
#  'ashu bhai this iitian entrepreneur speaking very accurately about bharat and modi economy with smes please help spread his word under ',
#  'probes nirav modiâ\x80\x99 applications for residency abroad india news ',
#  'the interview aired need certificate what hardcore licking performance ',
#  'what you say when your openly declares that india involved baluchistan insurgency what you say when modi declares dhaka that 1971 indian army was fighting with mukt bahini the garb freedom fighters was madness started india',
#  'yes willmake sure nobody will vote for unskilled incapable man likemodi \r\nthis was the biggest disaster our nation may awaits till then bhakts can keep tweeting',
#  'mike has zero interest the truth acted like little baby when provided evidence that would debunk his tulsimodi smears refused view even though there zero factual basis for his smears unsubscribed from his channel blocked him\r\n',
#  'more power modi and sandokan ',
#  'you are right suggest you same support modi',
#  'actually omar abdulla had prepared from news paper when was young was given mms during upa mms did not launch rahul wanted play with finally when modi became threw away from terrace happy why publishes such rubbish statements',
#  'have question when will start sending money like modi lakh like after years congress govt big question who poor your list rahul how know the reality people cant meet them after several requests your emails haha big jock',
#  'india drdo has created history sat great thanks narendra bhai modi',
#  'seems did not hear modi todayà¥¤ has said leave pakistan aside will die its own death something the sleeves dhume ',
#  'the worst award goes modi',
#  'this guy truly the best asset the modi lol ',
#  'modi scores another achievement his 100th scam now out inr 3400000000 water supply scam under gujarat bjp govt excm suresh mehta cites audit reportâ\x80¼ï¸\x8fshameless chowkidar  ',
#  'said first going expose then will build toilets jharkhand and then said something modi will idk later â\x80\x99 pay for education bezzati seh lunga kyun legit hai par process lamba hai chalega kya',
#  'pakistan china and indian opposition want modi defeat',
#  'hello sir youth likestartup ',
#  'think this movement become only for twitter and other social media movement not actually real potrait',
#  'hum main mat jana this not the modi like not the modi may vote',
#  'the magic modi effect ',
#  'journalist lolll arnab goswami sold out bitch for modi',
#  'modiâ\x80\x99 â\x80\x98address nationâ\x80\x99 didnâ\x80\x99 violate model code ',
#  'from modis speech india becomes 4th nation enter elite space power club with antisatellite weapon announces modi drdo has successfully shot down satellite ',
#  'yeah the lady who was nowhere seen for years and didnâ\x80\x99 give damn about anything big factor against modiwhat joke donâ\x80\x99 take people for fooltheyâ\x80\x99 smarter than you think',
#  'modi bhakt says that modi have family then why will being thief but say gabbarshingh have family then why was robbing ramgrah',
#  'sirji you guys sold chaddi dhari anna first placeindians are still paying for mistakemodi gang just interest that',
#  'chup tonti chor all know how much pain you all are going through modi itna bada kaam kar diya india space super power bana diya tum logo taqleef hona lazmi haters burn  ',
#  'address meetings march april vijayawada prime minister narendra modiâ\x80¦ ',
#  'why modi snatching away other peoples credit for his election gains\r\nshameless',
#  'our airforce has already given answer persons asking for proof india needs dynamic leader like you for next years nation proud our narendra modi',
#  'the people didnt know they were voting for pak lovers who knew they would fall low even those who voted for modi had idea that opposition will become antiindia also how did you arrive voters chaturvedi school mathematics',
#  'yeswe all countrymen will vote the above issues not modi his bjps fake lies propoganda nationalsm because can not give employmentit cant free from farm distress high prices clean drinking water etc',
#  'will give our money only mrvijay mallya mrnirav modis not poor indians',
#  'pls modi once again you give back our india golden bird only you can ',
#  'yes sir before modi the bluff pak will relate with nuke was forced upon now its cristal clear now will the same its possible under modi',
#  'give credit asat nehru because created isro despite dying years before was established not modi just gave permission test fire congress logic ',
#  'what about the court london where nirav modi reply judge says gave 458 crores congress â\x80\x99 record for once this true spread this',
#  'surgical strikes carried out during upa regime without publicity kcr tells modi the news minute ',
#  ...]

# %%
# Label the documents based on presence of polarity words
labels = []
for doc in documents:
    preprocessed_doc = preprocess_text(doc)
    if any(word in preprocessed_doc for word in positive_words):
        labels.append('positive')
    elif any(word in preprocessed_doc for word in negative_words):
        labels.append('negative')
    else:
        labels.append('neutral')  # If neither positive nor negative words are found

# %%
labels
# Out:
# ['neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  ...]

# %%
# Create TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Transform the documents into TF-IDF vectors
tfidf_matrix = vectorizer.fit_transform(documents)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, labels, test_size=0.2, random_state=42)

# %%
# Initialize and train the Support Vector Machine classifier
classifier = SVC(kernel='linear')
classifier.fit(X_train, y_train)

# Predict the labels for the test set
y_pred = classifier.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7526236881559221

# %%
# Example prediction
new_document = "I had bad experience"
preprocessed_new_doc = preprocess_text(new_document)
new_doc_tfidf = vectorizer.transform([preprocessed_new_doc])
prediction = classifier.predict(new_doc_tfidf)
print("Predicted sentiment for the document:", prediction[0])
# Out:
# Predicted sentiment for the document: negative

# %%
# Example prediction
new_document = "I had good breakfast in my home"
preprocessed_new_doc = preprocess_text(new_document)
new_doc_tfidf = vectorizer.transform([preprocessed_new_doc])
prediction = classifier.predict(new_doc_tfidf)
print("Predicted sentiment for the document:", prediction[0])
# Out:
# Predicted sentiment for the document: positive
